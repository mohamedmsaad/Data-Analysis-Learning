# %%
import pandas as pd

df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# 4    January 1, 2020          2008  PG-13    123 min
#
#                                            listed_in  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
# 4                                             Dramas
#
#                                          description
# 0  In a future where the elite inhabit an island ...
# 1  After a devastating earthquake hits Mexico Cit...
# 2  When an army recruit is found dead, his fellow...
# 3  In a postapocalyptic world, rag-doll robots hi...
# 4  A brilliant group of students become card-coun...

# %%
print("Nombre total de Titres : ", len(df))
# Out:
# Nombre total de Titres :  7787

# %%
print("L'année comptant le plus de films est : ", df["release_year"].value_counts().idxmax())
# Out:
# L'année comptant le plus de films est :  2018

# %%
print("Les 10 pays qui produisent les plus de films sont :\n\n",df['country'].value_counts().head(10).to_string())
# Out:
# Les 10 pays qui produisent les plus de films sont :
#
#  United States     2555
# India              923
# United Kingdom     397
# Japan              226
# South Korea        183
# Canada             177
# Spain              134
# France             115
# Egypt              101
# Turkey             100

# %%
movies = df[df['type'] == 'Movie'].copy()
movies['duration_int'] = movies['duration'].str.replace(' min', '', regex=False).astype(int)
movies.sort_values(by='duration_int', ascending=False).head(5)
# Out:
#      show_id   type                       title                director  \
# 957     s958  Movie  Black Mirror: Bandersnatch                     NaN
# 6850   s6851  Movie      The School of Mischief  Houssam El-Din Mustafa
# 4490   s4491  Movie              No Longer kids         Samir Al Asfory
# 3694   s3695  Movie          Lock Your Girls In       Fouad El-Mohandes
# 5108   s5109  Movie             Raya and Sakina           Hussein Kamal
#
#                                                    cast        country  \
# 957   Fionn Whitehead, Will Poulter, Craig Parkinson...  United States
# 6850  Suhair El-Babili, Adel Emam, Saeed Saleh, Youn...          Egypt
# 4490  Said Saleh, Hassan Moustafa, Ahmed Zaki, Youne...          Egypt
# 3694  Fouad El-Mohandes, Sanaa Younes, Sherihan, Ahm...            NaN
# 5108  Suhair El-Babili, Shadia, Abdel Moneim Madboul...            NaN
#
#              date_added  release_year rating duration  \
# 957   December 28, 2018          2018  TV-MA  312 min
# 6850       May 21, 2020          1973  TV-14  253 min
# 4490       May 21, 2020          1979  TV-14  237 min
# 3694       May 21, 2020          1982  TV-PG  233 min
# 5108       May 21, 2020          1984  TV-14  230 min
#
#                                             listed_in  \
# 957    Dramas, International Movies, Sci-Fi & Fantasy
# 6850           Comedies, Dramas, International Movies
# 4490           Comedies, Dramas, International Movies
# 3694  Comedies, International Movies, Romantic Movies
# 5108           Comedies, Dramas, International Movies
#
#                                             description  duration_int
# 957   In 1984, a young programmer begins to question...           312
# 6850  A high school teacher volunteers to transform ...           253
# 4490  Hoping to prevent their father from skipping t...           237
# 3694  A widower believes he must marry off his three...           233
# 5108  When robberies and murders targeting women swe...           230

# %%
# 1. On garde uniquement les films
movies_df = df[df['type'] == 'Movie'].copy()

# 2. On supprime le ' min' et convertit en entier
movies_df['duration_minutes'] = movies_df['duration'].str.replace(' min', '').astype(int)

# 3. Afficher les 5 premières lignes
print(movies_df[['title', 'duration', 'duration_minutes']].head())

print("Statistiques de durée des films :")
print(movies_df['duration_minutes'].describe())
# Out:
#    title duration  duration_minutes
# 1   7:19   93 min                93
# 2  23:59   78 min                78
# 3      9   80 min                80
# 4     21  123 min               123
# 6    122   95 min                95
# Statistiques de durée des films :
# count    5377.000000
# mean       99.307978
# std        28.530881
# min         3.000000
# 25%        86.000000
# 50%        98.000000
# 75%       114.000000
# max       312.000000
# Name: duration_minutes, dtype: float64

# %%
import matplotlib.pyplot as plt

plt.hist(movies_df['duration_minutes'], bins=30, color='skyblue', edgecolor='black')
plt.title("Distribution de la durée des films")
plt.xlabel("Durée (minutes)")
plt.ylabel("Nombre de films")
plt.show()
